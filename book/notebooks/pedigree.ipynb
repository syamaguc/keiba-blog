# %% [markdown]
# # 分析対象

# %%
import pandas as pd

# %%
df = pd.read_csv("../tmp/result.csv")
# Out:
# /var/folders/tn/j8hdvbw52z938h6gxwsg4b4w0000gn/T/ipykernel_47224/891290719.py:1: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../tmp/result.csv")

# %%
# とりあえずはサンプルの多い、父TOP10か母父TOP10から
x = 10

# ------------------------------------------------------------------
# 1. 父
# ------------------------------------------------------------------
top_father = (
    df.groupby('父馬名')
      .size()                          # 件数を数える
      .reset_index(name='count')       # DataFrame に戻す
      .sort_values('count', ascending=False)  # 降順ソート
      .head(x)                         # 上位 x 件だけ取り出す
)

# ------------------------------------------------------------------
# 2. 母父
# ------------------------------------------------------------------
top_grand_father = (
    df.groupby('母の父馬名')
      .size()
      .reset_index(name='count')
      .sort_values('count', ascending=False)
      .head(x)
)


# ------------------------------------------------------------------
# 3. 父 x 母父
# ------------------------------------------------------------------
top_multi = (
    df.groupby(['父馬名', '母の父馬名'])
      .size()
      .reset_index(name='count')
      .sort_values('count', ascending=False)
      .head(x)
)

# %%
top_father
# Out:
#              父馬名  count
# 781    ディープインパクト  16810
# 841       ハーツクライ  13843
# 754      ダイワメジャー  12211
# 588     キングカメハメハ  11665
# 1001     ロードカナロア  11357
# 977      ルーラーシップ  10326
# 843      ハービンジャー   9777
# 593    キンシャサノキセキ   8513
# 577          キズナ   7221
# 600         クロフネ   7201
# 706      ステイゴールド   7022
# 557      オルフェーヴル   6773
# 886      ブラックタイド   6713
# 629    ゴールドアリュール   6678
# 543      エピファネイア   6363
# 897      ヘニーヒューズ   6317
# 1016   ヴィクトワールピサ   5771
# 854          パイロ   5443
# 826     ネオユニヴァース   5173
# 684    シンボリクリスエス   5153
# 812       ドゥラメンテ   5085
# 735      ゼンノロブロイ   5050
# 924    マンハッタンカフェ   5043
# 697    スクリーンヒーロー   5007
# 687      ジャスタウェイ   5005
# 496     アドマイヤムーン   4959
# 671   シニスターミニスター   4888
# 637     サウスヴィグラス   4881
# 942    メイショウボーラー   4826
# 951         モーリス   4719

# %%
top_grand_father
# Out:
#           母の父馬名  count
# 1164  サンデーサイレンス  21166
# 1106   キングカメハメハ  14846
# 1006   アグネスタキオン  13747
# 1117       クロフネ  12836
# 1398      フジキセキ  12608
# 1294  ディープインパクト  12508
